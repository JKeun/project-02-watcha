# %% [markdown]
# ## Test set (11편의 영화정보)

# %%
pd.read_excel('../resource/test_df.xlsx')
# Out:
#                 title  avg_rating  \
# 0               아노말리사     3.72008
# 1             방안의 코끼리     2.50431
# 2             거짓말은자란다     3.05238
# 3                보이 7     2.52941
# 4              엑스 마키나     3.46250
# 5                  세븐     4.05060
# 6   어벤져스 : 에이지 오브 울트론     3.78890
# 7              인사이드아웃     4.15653
# 8                 빅쇼트     3.89942
# 9                주토피아     4.31814
# 10               레버넌트     3.77577
# 11                 캐롤     4.09901
#
#                                                 text  watcha_rating  my_rating
# 0          찰리카프먼 제니퍼제이슨리 데이빗듈리스 톰누난 청소년관람불가 애니메이션 미국       3.423718          4
# 1                      권칠인 곽시양 신동미 김태한 청소년관람불가 미상 한국       2.700460          2
# 2         이시카와준이치 토다에리카 마츠자카토리 오자와유키요시 15세관람가 코미디 일본       3.005566          4
# 3            로렌스블록 매티스반드샌드바쿠이젠 엘라준헨라드 티호헤르난트 SF 네덜란드       1.942025          2
# 4     알렉스가랜드 노덜클리슨 알리시아비칸데르 오스카아이삭 청소년관람불가 드라마 미국 영국       3.397823          3
# ...
